# %%
import pandas as pd

# %%
dataset = pd.read_csv('Data Test Prediksi Prototype 3a .csv')
dataset2 = pd.read_csv('percobaanTest1.csv')

# %%
dataset = dataset.dropna()

# %%
syalala = dataset2.RR

# %%
dataset2
# Out:
#      Index         RR
# 0        0   1.231922
# 1        1   1.236758
# 2        2   1.732485
# 3        3   2.178684
# 4        4   1.544487
# 5        5   2.783481
# 6        6   1.771935
# 7        7   2.173797
# 8        8   3.222460
# 9        9   2.055086
# 10      10   1.892425
# 11      11   1.999328
# 12      12   1.386588
# 13      13   5.086976
# 14      14   1.368488
# 15      15   2.924698
# 16      16  74.274119
# 17      17  11.118064
# 18      18   3.453962
# 19      19   5.487297
# 20      20   2.964107
# 21      21   7.102449
# 22      22   2.526271
# 23      23   1.661832
# 24      24   5.934447
# 25      25   1.805233
# 26      26   1.718304
# 27      27   1.908219
# 28      28   2.207709
# 29      29   2.235175
# ..     ...        ...
# 117    117   3.650608
# 118    118   2.754067
# 119    119   3.141416
# 120    120   8.318906
# 121    121   8.357904
# 122    122   1.403184
# 123    123   3.980984
# 124    124   6.942727
# 125    125   5.260861
# ...

# %%
import numpy as np
tes_prediksi = np.hstack((dataset,dataset2))

# %%
pd.DataFrame(tes_prediksi).to_csv("tes_prediksi.csv",header=None)

# %%
loss = pd.read_csv('loss.csv')
acc = pd.read_csv('acc.csv')
valloss = pd.read_csv('valloss.csv')
valacc = pd.read_csv('valacc.csv')

# %%
tes_model1 = np.hstack((loss,acc))
tes_model2 = np.hstack((valloss,valacc))

# %%
tes_modelfix = np.hstack((tes_model1,tes_model2))

# %%
pd.DataFrame(tes_modelfix).to_csv("tes_model_fix.csv",header=None)

# %%
jancuks = pd.read_csv('tes_model_fix.csv')

# %%
jancuks
# Out:
#      index  index0      loss  index1       acc  index2   valloss  index3  \
# 0        0     0.0  0.011029     0.0  0.231890     0.0  0.008553     0.0
# 1        1     1.0  0.010548     1.0  0.231890     1.0  0.008525     1.0
# 2        2     2.0  0.010198     2.0  0.231890     2.0  0.008009     2.0
# 3        3     3.0  0.009845     3.0  0.231890     3.0  0.008093     3.0
# 4        4     4.0  0.009811     4.0  0.231890     4.0  0.008024     4.0
# 5        5     5.0  0.009775     5.0  0.231890     5.0  0.007888     5.0
# 6        6     6.0  0.009657     6.0  0.231890     6.0  0.007868     6.0
# 7        7     7.0  0.009623     7.0  0.231890     7.0  0.007840     7.0
# 8        8     8.0  0.009527     8.0  0.231890     8.0  0.007963     8.0
# 9        9     9.0  0.009824     9.0  0.231890     9.0  0.007856     9.0
# 10      10    10.0  0.009520    10.0  0.231890    10.0  0.007908    10.0
# 11      11    11.0  0.009494    11.0  0.231890    11.0  0.008151    11.0
# ...
